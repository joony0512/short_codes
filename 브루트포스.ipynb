# %% [markdown]
# <a href="https://colab.research.google.com/github/joony0512/short_codes/blob/main/%EB%B8%8C%EB%A3%A8%ED%8A%B8%ED%8F%AC%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 블랙잭
#
#
# 카지노에서 제일 인기 있는 게임 블랙잭의 규칙은 상당히 쉽다. 카드의 합이 21을 넘지 않는 한도 내에서, 카드의 합을 최대한 크게 만드는 게임이다. 블랙잭은 카지노마다 다양한 규정이 있다.
# 한국 최고의 블랙잭 고수 김정인은 새로운 블랙잭 규칙을 만들어 상근, 창영이와 게임하려고 한다.
# 김정인 버전의 블랙잭에서 각 카드에는 양의 정수가 쓰여 있다. 그 다음, 딜러는 N장의 카드를 모두 숫자가 보이도록 바닥에 놓는다. 그런 후에 딜러는 숫자 M을 크게 외친다.
# 이제 플레이어는 제한된 시간 안에 N장의 카드 중에서 3장의 카드를 골라야 한다. 블랙잭 변형 게임이기 때문에, 플레이어가 고른 카드의 합은 M을 넘지 않으면서 M과 최대한 가깝게 만 들어야 한다.
# N장의 카드에 써져 있는 숫자가 주어졌을 때, M을 넘지 않으면서 M에 최대한 가까운 카드 3장의 합을 구해 출력하시오.
# 입력
# 첫째 줄에 카드의 개수 N(3 <= N <= 100)과 M(10 <= M <= 300,000)이 주어진다. 둘째 줄에는 카드에 쓰여 있는 수가 주어지며, 이 값은 100,000을 넘지 않는 양의 정수이다.
# 합이 M을 넘지 않는 카드 3장을 찾을 수 있는 경우만 입력으로 주어진다.
# 출력
# 첫째 줄에 M을 넘지 않으면서 M에 최대한 가까운 카드 3장의 합을 출력한다.

# %%
import itertools

# 입력 받기
N, M = map(int, input().split())
cards = list(map(int, input().split()))

# 가능한 3장의 카드 조합 생성
combinations = list(itertools.combinations(cards, 3))

# 최대값 초기화
max_sum = 0

# 가능한 모든 조합에 대해 합을 계산하고 M을 넘지 않는 경우 최대값 갱신
for combo in combinations:
    current_sum = sum(combo)
    if current_sum <= M:
        max_sum = max(max_sum, current_sum)

# 최대 합 출력
print(max_sum)
# Out:
# 5 21
# 5 7 9 10 6
# 21

# %% [markdown]
# # 분해합
#
# 문제
# 어떤 자연수 N이 있을 때, 그 자연수 N의 분해합은 N과 N을 이루는 각 자리수의 합을 의미한다. 어떤 자연수 M의 분해합이 N인 경우, M을 N의 생성자라 한다. 예를 들어, 245의 분해합은 256(=245+2+4+5)이 된다. 따라서 245는 256의 생성자가 된다. 물론, 어떤 자연수의 경우에는 생성자가 없을 수도 있다. 반대로, 생성자가 여러 개인 자연수도 있을 수 있다.
#
# 자연수 N이 주어졌을 때, N의 가장 작은 생성자를 구해내는 프로그램을 작성하시오.
#
# 입력
# 첫째 줄에 자연수 N(1 ≤ N ≤ 1,000,000)이 주어진다.
#
# 출력
# 첫째 줄에 답을 출력한다. 생성자가 없는 경우에는 0을 출력한다.

# %%
# m = abcd 라는 수의 분해합은 n = abcd + a + b + c + d (4자리인 경우 a * 10^3 + b * 10^2 + c * 10^1 + d ^10^0  + a + b + c + d)
N = int(input())

for a in range(1, N + 1):
    b = a + sum(map(int, str(a)))

# %%
def find_smallest_constructor(N):
    for candidate in range(1, N + 1):
        decomposed_sum = candidate + sum(map(int, str(candidate)))
        if decomposed_sum == N:
            return candidate
    return 0

N = int(input())
result = find_smallest_constructor(N)
print(result)
# Out:
# 216
# 198

# %%
str(5)
# Out:
# '5'

# %%
str(66)
# Out:
# '66'

# %%
sum(map(int, str(66)))
# Out:
# 12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a, b, c, d, e, f = map(int, input().split())

y = (c*d - a*f)/(b*d - a*e)
x = (f - e*y)/d

print(int(x), int(y))
# Out:
# 1 3 -1 4 1 7
# 2 -1

# %%
a = input().split()
# Out:
# 5 6 7

# %%
a
# Out:
# ['5', '6', '7']

# %%
a = 5
b = 6
print(a, b)
# Out:
# 5 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
N, M = map(int, input().split())

board =[]
for i in range(N):
    board.append(list(input()))
# Out:
# 11 12
# BWWBWWBWWBWW
# BWWBWBBWWBWW
# WBWWBWBBWWBW
# BWWBWBBWWBWW
# WBWWBWBBWWBW
# BWWBWBBWWBWW
# WBWWBWBBWWBW
# BWWBWBWWWBWW
# WBWWBWBBWWBW
# BWWBWBBWWBWW
# WBWWBWBBWWBW

# %%
board
# Out:
# [['B', 'W', 'W', 'B', 'W', 'W', 'B', 'W', 'W', 'B', 'W', 'W'],
#  ['B', 'W', 'W', 'B', 'W', 'B', 'B', 'W', 'W', 'B', 'W', 'W'],
#  ['W', 'B', 'W', 'W', 'B', 'W', 'B', 'B', 'W', 'W', 'B', 'W'],
#  ['B', 'W', 'W', 'B', 'W', 'B', 'B', 'W', 'W', 'B', 'W', 'W'],
#  ['W', 'B', 'W', 'W', 'B', 'W', 'B', 'B', 'W', 'W', 'B', 'W'],
#  ['B', 'W', 'W', 'B', 'W', 'B', 'B', 'W', 'W', 'B', 'W', 'W'],
#  ['W', 'B', 'W', 'W', 'B', 'W', 'B', 'B', 'W', 'W', 'B', 'W'],
#  ['B', 'W', 'W', 'B', 'W', 'B', 'W', 'W', 'W', 'B', 'W', 'W'],
#  ['W', 'B', 'W', 'W', 'B', 'W', 'B', 'B', 'W', 'W', 'B', 'W'],
#  ['B', 'W', 'W', 'B', 'W', 'B', 'B', 'W', 'W', 'B', 'W', 'W'],
#  ['W', 'B', 'W', 'W', 'B', 'W', 'B', 'B', 'W', 'W', 'B', 'W']]

# %%
color_changed_nums = []

w_start = ['W', 'B', 'W', 'B', 'W', 'B', 'W', 'B']
b_start = ['B', 'W', 'B', 'W', 'B', 'W', 'B', 'W']

for i in range(N - 7): #행시작 위치
    for j in range(M - 7): #열시작위치
        w_count = 0 # w로 시작하는 경우
        b_count = 0 # b로 시작하는 경우
        for k in range(8):
            chess_row = board[i + k][j:j + 8] # i행 8칸씩 탐색

            if k % 2 == 0: # 탐색의 첫 칸부터 두칸씩 탐색
                for l in range(8):
                    if chess_row[l] != b_start[l]:
                        b_count += 1
                    if chess_row[l] != w_start[l]:
                        w_count += 1

            if k % 2 == 1: # 탐색의 두번째 칸부터 두칸씩 탐색
                for m in range(8):
                    if chess_row[m] != w_start[m]:
                        b_count += 1
                    if chess_row[m] != b_start[m]:
                        w_count += 1

        color_changed_nums.append(b_count)
        color_changed_nums.append(w_count)

print(min(color_changed_nums))
# Out:
# 15
